# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/commit_test_folder/test
# Out:
# /content/drive/MyDrive/commit_test_folder/test

# %%
# !git clone https://Kweon0605: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@github.com/Kweon0605/test.git
# Out:
# Cloning into 'test'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !git config --global user.email 'dydwls6598@naver.com'
# !git config --global user.name 'Kweon0605'

# %%
# !git add Untitled0.ipynb
